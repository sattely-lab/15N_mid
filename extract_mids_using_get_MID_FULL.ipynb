# %%
import sys
import os

# %%
# !python /Users/curt/stanford/code/sattely_lab_github/scripts/get_MID_15N.py -r 0.1 -t 0.7 -m 20 -n 8 -s pheophytin_a_ion.sdf -f mzml_files/2019-09-03_full_experiment/A11.mzML -o mid_files/2019-09-03/A11.csv
# Out:
# [16:52:45] SMILES Parse Error: syntax error for input: 'pheophytin_a_ion.sdf'
#    C13_theo_mz  N15_theo_mz              analysis_date  m     mean_mz  \
# 0   871.573198   871.573198 2019-09-03 16:52:45.665690  0  871.574788
# 1   872.576553   872.570233 2019-09-03 16:52:45.665690  1  872.577826
# 2   873.579908   873.567268 2019-09-03 16:52:45.665690  2  873.580865
# 3   874.583262   874.564303 2019-09-03 16:52:45.665690  3  874.584097
# 4   875.586617   875.561337 2019-09-03 16:52:45.665690  4  875.586087
# 5   876.589972   876.558372 2019-09-03 16:52:45.665690  5  876.586607
# 6   877.593327   877.555407 2019-09-03 16:52:45.665690  6  877.587406
# 7   878.596682   878.552442 2019-09-03 16:52:45.665690  7  878.575283
# 8   879.600037   879.549477 2019-09-03 16:52:45.665690  8  879.587459
#
#         mid                                       mzml_file  raw_intensity  \
# 0  0.534799  mzml_files/2019-09-03_full_experiment/A11.mzML   6.139360e+07
# ...

# %%
my_files = !ls mzml_files/2019-09-03_full_experiment/

# %%
my_files
# Out:
# ['A11.mzML',
#  'A12.mzML',
#  'A13.mzML',
#  'A14.mzML',
#  'A15.mzML',
#  'A16.mzML',
#  'A21.mzML',
#  'A22.mzML',
#  'A23.mzML',
#  'A24.mzML',
#  'A25.mzML',
#  'A26.mzML',
#  'A31.mzML',
#  'A32.mzML',
#  'A33.mzML',
#  'A34.mzML',
#  'A35.mzML',
#  'A36.mzML',
#  'A41.mzML',
#  'A42.mzML',
#  'A43.mzML',
#  'A44.mzML',
#  'A45.mzML',
#  'A46.mzML',
#  'B11.mzML',
#  'B12.mzML',
#  'B13.mzML',
#  'B14.mzML',
#  'B15.mzML',
#  'B16.mzML',
#  'B21.mzML',
#  'B22.mzML',
#  'B23.mzML',
#  'B24.mzML',
#  'B25.mzML',
#  'B26.mzML',
#  'B31.mzML',
#  'B32.mzML',
#  'B33.mzML',
#  'B34.mzML',
#  'B35.mzML',
#  'B36.mzML',
#  'B41.mzML',
#  'B42.mzML',
#  'B43.mzML',
#  'B44.mzML',
#  'B45.mzML',
#  'B46.mzML',
#  'C11.mzML',
#  'C12.mzML',
#  'C13.mzML',
#  'C14.mzML',
#  'C15.mzML',
#  'C16.mzML',
#  'C21.mzML',
#  'C22.mzML',
#  'C23.mzML',
#  'C24.mzML',
#  'C25.mzML',
#  'C26.mzML',
#  'C31.mzML',
#  'C32.mzML',
#  'C33.mzML',
#  'C34.mzML',
#  'C35.mzML',
#  'C36.mzML',
# ...

# %%
for fname in my_files:
    out_name = fname.replace('.mzML', '.csv')
    o_arg = os.path.join('mid_files/2019-09-03', out_name)
    f_arg = os.path.join('mzml_files/2019-09-03_full_experiment/', fname)
    # !python /Users/curt/stanford/code/sattely_lab_github/scripts/get_MID_15N.py -r 0.1 -t 0.7 -m 20 -n 7 -s pheophytin_a_ion.sdf -f {f_arg} -o {o_arg}
# Out:
# [16:53:57] SMILES Parse Error: syntax error for input: 'pheophytin_a_ion.sdf'
#    C13_theo_mz  N15_theo_mz              analysis_date  m     mean_mz  \
# 0   871.573198   871.573198 2019-09-03 16:53:57.381304  0  871.574788
# 1   872.576553   872.570233 2019-09-03 16:53:57.381304  1  872.577826
# 2   873.579908   873.567268 2019-09-03 16:53:57.381304  2  873.580865
# 3   874.583262   874.564303 2019-09-03 16:53:57.381304  3  874.584097
# 4   875.586617   875.561337 2019-09-03 16:53:57.381304  4  875.586087
# 5   876.589972   876.558372 2019-09-03 16:53:57.381304  5  876.586607
# 6   877.593327   877.555407 2019-09-03 16:53:57.381304  6  877.587406
# 7   878.596682   878.552442 2019-09-03 16:53:57.381304  7  878.575283
#
#         mid                                       mzml_file  raw_intensity  \
# 0  0.534810  mzml_files/2019-09-03_full_experiment/A11.mzML   6.139360e+07
# 1  0.337157  mzml_files/2019-09-03_full_experiment/A11.mzML   3.870398e+07
# ...
